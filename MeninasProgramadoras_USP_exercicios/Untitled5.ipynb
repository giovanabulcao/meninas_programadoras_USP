# %%
c = float(input())
tx = float(input())

m1= c*(1+tx)**1
m2= c*(1+tx)**2
m3= c*(1+tx)**3

print("%.2f" % m1)
print("%.2f" % m2)
print("%.2f" % m3)
# Out:
# 123.45
# .05
# 129.62
# 136.10
# 142.91
