# %%
n1 = int(input('digite um número: ' ))
n2 = int(input('digite o próximo número: '))
maior = 0
if n1 > n2:
   maior = n1
elif n1 < n2:
   maior = n2
else:
   print('Os números são iguais')
print('O maior número entre ',n1,' e ',n2, 'é ',maior)
# Out:
# digite um número: 3
# digite o próximo número: 5
# O maior número entre  3  e  5 é  5
