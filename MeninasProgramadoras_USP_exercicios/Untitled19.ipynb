# %%
aceitas = 0
solucao = input()

while solucao != 'timeout':
     if solucao == 'accepted':
       aceitas += 1
     solucao = input()

print(aceitas)
# Out:
# accepted
# accepted
# accepted
# wrong answer
# wrong answer
# timeout
# 3
