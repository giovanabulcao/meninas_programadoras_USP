# %%
n1 = int(input())
n2 = int(input())


If x = n2 + 1 or x1 = n2 - 1
    print("são consecutivos")

else:
    print("não são consecutivos")
# Out:
#   File "<ipython-input-7-393cf7026091>", line 5
#     If x = n2 + 1 and x1 = n2 - 1
#        ^
# SyntaxError: invalid syntax
