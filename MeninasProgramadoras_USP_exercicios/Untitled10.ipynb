# %% [markdown]
# num = input()
#
# if num == 'I'
#  print('1')
# elif num == 'V'
#   print('5')
# elif num == 'X'
#  print('5')
# elif num == 'L'
#  print('5')
# elif num == 'C'
#  print('5')
# elif num == 'D'
#  print('5')
# elif num == ''
#  print('5')

# %%
num = input()

if num == 'I':
 print('1')
elif num == 'V':
  print('5')
elif num == 'X':
 print('10')
elif num == 'L':
  print('50')
elif num == 'C':
 print('100')
elif num == 'D':
 print('500')
elif num == 'M':
  print('1000')
# Out:
# I
# 1

# %%
#equação de segundo grau ~ ax²+bx+c=0

a = float(input())
b = float(input())
c = float(input())


delta = b**2 - 4*a*c

if delta > 0:
  print('2')
elif delta == 0:
  print('1')
elif delta < 0:
  print('0')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-2bc9724b0349> in <cell line: 3>()
#       1 #equação de segundo grau ~ ax²+bx+c=0
#       2
# ----> 3 a = float(input())
#       4 b = float(input())
#       5 c = float(input())
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# ...

# %%
F = input()
V = input()

if V and V:
  print('VV')
elif V and F:
  print('?')
elif F and F:
  print('')
