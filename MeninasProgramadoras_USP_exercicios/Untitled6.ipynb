# %%
l1 = int(input())
l2 = int(input())
l3 = int(input())
l4 = int(input())
e1 = int(input())
e2 = int(input())
e3 = int(input())
e4 = int(input())

a = e1/l1*100
b = e2/l2*100
c = e3/l3*100
d = e4/l4*100

print("%.1f" % a)
print("%.1f" % b)
print("%.1f" % c)
print("%.1f" % d)
# Out:
# 10
# 15
# 20
# 5
# 9
# 9
# 9
# 5
# 90.0
# 60.0
# 45.0
# 100.0
