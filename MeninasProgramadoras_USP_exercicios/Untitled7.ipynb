# %%
cor = input() #cor da bandeira

if cor == 'amarelo':
  print('losango')
elif cor =='azul':
     print('circunferência')
elif cor =='verde':
    print('retângulo')
elif cor =='branco':
    print('faixa')
else:
   print( 'não tem essa cor')
# Out:
# branco
# faixa

# %%
dinheiro = int(input())
total = int(input())

if dinheiro >= total:
  print('pode comprar tudo')
else:
  print('saldo insuficiente')
# Out:
# 123
# 243
# saldo insuficiente

# %%
cnt = int(input())
crr = int(input())

x = cnt - crr

if cnt >= crr:
  print(f'se você comprar tudo o saldo será: {x}' )
else:
  print('seu saldo é insuficiente para essa compra')
# Out:
# 100
# 87
# se você comprar tudo o saldo será: 13

# %%
hr = int(input())
min = int(input())

min = hr/60
90 min = 1
# Out:
#   File "<ipython-input-46-2ddd43a2be88>", line 5
#     90 min = 1
#        ^
# SyntaxError: invalid syntax

# %%
letra = input()

if letra == 'A' or letra == 'a':
   print('LEFT')
elif letra == 'S'or letra == 's':
  print('DOWN')
elif letra == 'w'or letra == 'W':
  print('UP')
elif letra == 'D'or letra == 'd':
  print('RIGHT')
else:
  print('?')
# Out:
# q
# ?
